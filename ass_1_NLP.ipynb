# %%
pip install nltk
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.12/dist-packages (3.9.1)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from nltk) (8.3.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from nltk) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.12/dist-packages (from nltk) (2025.11.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from nltk) (4.67.3)

# %%
import nltk

from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer, WordNetLemmatizer

nltk.download('punkt')
nltk.download('wordnet')
nltk.download('omw-1.4')
nltk.download('punkt_tab')
corpus = """
Natural Language Processing is a fascinating field.
It helps computers understand human language.
Students are studying NLP and building projects.
"""

tokens = word_tokenize(corpus)

print("Tokenization")
print(tokens)

stemmer = PorterStemmer()
stemmed_words = [stemmer.stem(word) for word in tokens]

print("\nStemming")
print(stemmed_words)

lemmatizer = WordNetLemmatizer()
lemmatized_words = [lemmatizer.lemmatize(word) for word in tokens]

print("Lemmatization")
print(lemmatized_words)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# Tokenization
# ['Natural', 'Language', 'Processing', 'is', 'a', 'fascinating', 'field', '.', 'It', 'helps', 'computers', 'understand', 'human', 'language', '.', 'Students', 'are', 'studying', 'NLP', 'and', 'building', 'projects', '.']
#
# Stemming
# ['natur', 'languag', 'process', 'is', 'a', 'fascin', 'field', '.', 'it', 'help', 'comput', 'understand', 'human', 'languag', '.', 'student', 'are', 'studi', 'nlp', 'and', 'build', 'project', '.']
# Lemmatization
# ['Natural', 'Language', 'Processing', 'is', 'a', 'fascinating', 'field', '.', 'It', 'help', 'computer', 'understand', 'human', 'language', '.', 'Students', 'are', 'studying', 'NLP', 'and', 'building', 'project', '.']
