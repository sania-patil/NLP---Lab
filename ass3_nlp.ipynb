# %%
import re
from collections import defaultdict

text = """
Natural language processing helps computers understand human language.
Natural language models are used in many applications.
Language models predict the next word in a sequence.
"""

N = 3
input_sequence = "language models predict"

print("\nSTEP 1: Preprocessing Text\n")

text = text.lower()
text = re.sub(r'[^a-zA-Z\s]', '', text)
words = text.split()

print("Words:")
print(words)

print("\nSTEP 2: Generating N-grams\n")

ngram_counts = defaultdict(lambda: defaultdict(int))

for i in range(len(words) - N + 1):
    context = tuple(words[i:i+N-1])
    next_word = words[i+N-1]

    ngram_counts[context][next_word] += 1
    print(f"{context} → {next_word}")

print("\nSTEP 3: Calculating Probabilities\n")

ngram_probabilities = defaultdict(dict)

for context in ngram_counts:
    total_count = sum(ngram_counts[context].values())
    print(f"\nContext: {context}")

    for next_word in ngram_counts[context]:
        prob = ngram_counts[context][next_word] / total_count
        ngram_probabilities[context][next_word] = prob
        print(f"{next_word} → {ngram_counts[context][next_word]}/{total_count} = {prob:.2f}")

print("\nSTEP 4: Predicting Next Word\n")

input_words = input_sequence.lower().split()
context = tuple(input_words[-(N-1):])

print("Input Sequence:", input_sequence)
print("Context:", context)

if context in ngram_probabilities:
    next_word = max(ngram_probabilities[context],
                    key=ngram_probabilities[context].get)
    print("Predicted Next Word:", next_word)
else:
    print("No prediction available")
# Out:
# STEP 1: Preprocessing Text
#
# Words:
# ['natural', 'language', 'processing', 'helps', 'computers', 'understand', 'human', 'language', 'natural', 'language', 'models', 'are', 'used', 'in', 'many', 'applications', 'language', 'models', 'predict', 'the', 'next', 'word', 'in', 'a', 'sequence']
#
# STEP 2: Generating N-grams
#
# ('natural', 'language') → processing
# ('language', 'processing') → helps
# ('processing', 'helps') → computers
# ('helps', 'computers') → understand
# ('computers', 'understand') → human
# ('understand', 'human') → language
# ('human', 'language') → natural
# ('language', 'natural') → language
# ('natural', 'language') → models
# ('language', 'models') → are
# ('models', 'are') → used
# ('are', 'used') → in
# ('used', 'in') → many
# ('in', 'many') → applications
# ('many', 'applications') → language
# ('applications', 'language') → models
# ('language', 'models') → predict
# ('models', 'predict') → the
# ('predict', 'the') → next
# ('the', 'next') → word
# ('next', 'word') → in
# ('word', 'in') → a
# ('in', 'a') → sequence
#
# STEP 3: Calculating Probabilities
#
#
# Context: ('natural', 'language')
# processing → 1/2 = 0.50
# models → 1/2 = 0.50
#
# Context: ('language', 'processing')
# helps → 1/1 = 1.00
#
# Context: ('processing', 'helps')
# computers → 1/1 = 1.00
#
# Context: ('helps', 'computers')
# understand → 1/1 = 1.00
#
# Context: ('computers', 'understand')
# human → 1/1 = 1.00
#
# Context: ('understand', 'human')
# language → 1/1 = 1.00
#
# Context: ('human', 'language')
# natural → 1/1 = 1.00
#
# Context: ('language', 'natural')
# language → 1/1 = 1.00
#
# Context: ('language', 'models')
# are → 1/2 = 0.50
# predict → 1/2 = 0.50
#
# Context: ('models', 'are')
# used → 1/1 = 1.00
#
# Context: ('are', 'used')
# in → 1/1 = 1.00
#
# Context: ('used', 'in')
# many → 1/1 = 1.00
#
# Context: ('in', 'many')
# applications → 1/1 = 1.00
#
# Context: ('many', 'applications')
# language → 1/1 = 1.00
#
# Context: ('applications', 'language')
# models → 1/1 = 1.00
#
# Context: ('models', 'predict')
# the → 1/1 = 1.00
#
# Context: ('predict', 'the')
# next → 1/1 = 1.00
#
# Context: ('the', 'next')
# word → 1/1 = 1.00
#
# Context: ('next', 'word')
# in → 1/1 = 1.00
#
# Context: ('word', 'in')
# a → 1/1 = 1.00
#
# Context: ('in', 'a')
# sequence → 1/1 = 1.00
#
# STEP 4: Predicting Next Word
#
# Input Sequence: language models predict
# Context: ('models', 'predict')
# Predicted Next Word: the
